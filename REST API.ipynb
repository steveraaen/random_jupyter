# %% [markdown]
# # Get the latest NYC parking tickets

# %%
import requests

# %%
url = 'https://data.cityofnewyork.us/resource/qpyv-8eyi'

# %%
response = requests.get(url).json()

# %%
for ticket in response:
    print(ticket['violation_time'])
# Out:
# 1000A
# 1011A
# 0107A
# 0300A
# 0653A
# 0515P
# 0524P
# 0601P
# 0935A
# 1217P
# 0049A
# 0046A
# 0124A
# 0500A
# 1221A
# 1241A
# 1110A
# 0105A
# 1000P
# 0843A
# 0955P
# 0508P
# 1100A
# 1100A
# 1100A
# 0718A
# 0722A
# 0726A
# 0430A
# 0615P
# 0115A
# 0350A
# 0125A
# 1110A
# 0924A
# 0918A
# 0912P
# 0318P
# 0850A
# 1055A
# 0152A
# 0845A
# 0849A
# 0627A
# 0627A
# 1101A
# 0608P
# 0430P
# 0917A
# 0910A
# 0811A
# 0748A
# 1120A
# 1040A
# 1143A
# 1138A
# 0238P
# 1201P
# 1101A
# 1154A
# 0936A
# 0405P
# 1004P
# 0204P
# 0523P
# 0632P
# 0351P
# 0550A
# 0400P
# 1140A
# 0148P
# 1000P
# 0957P
# 1004A
# 0123P
# 0104P
# 1132A
# 0550P
# 1242P
# 1120P
# 1058A
# 0112A
# 1004P
# 1036A
# 0503P
# 0651A
# 0227P
# 0805A
# 0917P
# 0204P
# 0445A
# 0855A
# 1146A
# 0702P
# 0410A
# 0344A
# 1205A
# 0926P
# 1157A
# 0755A
# 0732P
# 0834P
# 0809P
# 0430P
# 0734P
# 0948P
# 0900P
# 0700P
# 0135A
# 0525P
# 0325P
# 0225A
# 0237A
# 0433P
# 0230A
# 0250A
# 0300A
# 0140A
# 0534P
# 0219A
# 1040P
# 1247P
# 0530P
# 1216P
# 0520P
# ...
